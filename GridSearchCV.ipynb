# %% [markdown]
# <a href="https://colab.research.google.com/github/likhitha867/AI-Estate-Vision/blob/main/GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['species'],axis=1)

# %%
y=df['species']

# %%
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn= KNeighborsClassifier()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')

# %%
model_svm.fit(x_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier=GridSearchCV((model_svm),{
    'C':[1,10,20,30],
    'kernel':['linear','rbf','poly'],
},cv=5,return_train_score=False)

# %%
classifier.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.01581783, 0.0131186 , 0.02288227, 0.02044592, 0.00895715,
#         0.02115445, 0.00337734, 0.00750899, 0.05332928, 0.01061153,
#         0.01193199, 0.04353318]),
#  'std_fit_time': array([0.00715535, 0.00830283, 0.00616253, 0.00693503, 0.0022128 ,
#         0.01391119, 0.0001647 , 0.00292076, 0.03588082, 0.00593412,
#         0.00825075, 0.02945445]),
#  'mean_score_time': array([0.00969152, 0.00865183, 0.01577401, 0.01643744, 0.00866075,
#         0.00774217, 0.00270782, 0.00865407, 0.01169853, 0.00672579,
#         0.00797052, 0.01149354]),
#  'std_score_time': array([0.00189753, 0.00412827, 0.0050501 , 0.00602803, 0.00422159,
#         0.00429301, 0.00013732, 0.00384649, 0.00392926, 0.00307196,
#         0.00371498, 0.00615233]),
#  'param_C': masked_array(data=[1, 1, 1, 10, 10, 10, 20, 20, 20, 30, 30, 30],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
# ...

# %%
results=pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.015818      0.007155         0.009692        0.001898        1
# 1        0.013119      0.008303         0.008652        0.004128        1
# 2        0.022882      0.006163         0.015774        0.005050        1
# 3        0.020446      0.006935         0.016437        0.006028       10
# 4        0.008957      0.002213         0.008661        0.004222       10
# 5        0.021154      0.013911         0.007742        0.004293       10
# 6        0.003377      0.000165         0.002708        0.000137       20
# 7        0.007509      0.002921         0.008654        0.003846       20
# 8        0.053329      0.035881         0.011699        0.003929       20
# 9        0.010612      0.005934         0.006726        0.003072       30
# 10       0.011932      0.008251         0.007971        0.003715       30
# 11       0.043533      0.029454         0.011494        0.006152       30
#
# ...

# %%
classifier.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
classifier.best_score_
# Out:
# np.float64(0.9800000000000001)

# %%
knn=GridSearchCV((model_knn),{
    'n_neighbors':[3,5,7,10,13],
    'weights':['uniform','distance'],
     'algorithm':['auto','ball_tree','kd_tree','brute'],
    'metric':['minkowski','euclidean','manhattan']
},cv=5,return_train_score=True)

# %%
knn.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['minkowski', 'euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 10, 13],
#                          'weights': ['uniform', 'distance']},
#              return_train_score=True)

# %%
knn.cv_results_
# Out:
# {'mean_fit_time': array([0.00587478, 0.00426965, 0.00495896, 0.00418787, 0.0038662 ,
#         0.00393672, 0.00652776, 0.00939908, 0.00857978, 0.00487304,
#         0.00305738, 0.00704584, 0.00792232, 0.01013837, 0.00697718,
#         0.00704918, 0.00421467, 0.00385427, 0.00344095, 0.00775609,
#         0.00774746, 0.00590568, 0.00752854, 0.00848279, 0.00952868,
#         0.00599279, 0.00333838, 0.0029212 , 0.00295792, 0.00329299,
#         0.00306029, 0.00337176, 0.00346575, 0.00341263, 0.00372119,
#         0.00324788, 0.00375185, 0.00323105, 0.00334277, 0.00332909,
#         0.00296998, 0.00206909, 0.00211549, 0.0020628 , 0.00218892,
#         0.00221181, 0.00222201, 0.00214119, 0.00234022, 0.00234241,
#         0.00224214, 0.0022119 , 0.00300083, 0.00263553, 0.00215592,
#         0.00225816, 0.00222034, 0.00225272, 0.00225592, 0.00213428,
#         0.00209494, 0.00209484, 0.00210962, 0.00213528, 0.00213628,
#         0.00203295, 0.00223069, 0.00212274, 0.00213799, 0.00215535,
# ...

# %%
knn.best_params_
# Out:
# {'algorithm': 'auto',
#  'metric': 'minkowski',
#  'n_neighbors': 10,
#  'weights': 'distance'}

# %%
knn.best_score_
# Out:
# np.float64(0.9866666666666667)

# %%
result=pd.DataFrame(knn.cv_results_)
result
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.005875      0.003526         0.006779        0.002675
# 1         0.004270      0.000234         0.004759        0.000606
# 2         0.004959      0.001907         0.005461        0.000123
# 3         0.004188      0.000419         0.004175        0.000148
# 4         0.003866      0.000127         0.005870        0.000491
# ..             ...           ...              ...             ...
# 115       0.001882      0.000021         0.002109        0.000060
# 116       0.001889      0.000073         0.002875        0.000195
# 117       0.001921      0.000053         0.002173        0.000065
# 118       0.001946      0.000080         0.003017        0.000220
# 119       0.001949      0.000086         0.002183        0.000024
#
#     param_algorithm param_metric  param_n_neighbors param_weights  \
# 0              auto    minkowski                  3       uniform
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r=RandomizedSearchCV((model_svm),{
    'C':[1,10,20,30],
    'kernel':['linear','rbf','poly'],
},n_iter=4,cv=5,return_train_score=False)

# %%
classifier_r.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['linear', 'rbf', 'poly']})

# %%
results_r=pd.DataFrame(classifier_r.cv_results_)
results_r
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.012436      0.005448         0.004242        0.000464         poly
# 1       0.019469      0.012531         0.003701        0.000502         poly
# 2       0.005341      0.000445         0.003679        0.000244          rbf
# 3       0.019254      0.012926         0.003370        0.000240         poly
#
#    param_C                       params  split0_test_score  split1_test_score  \
# 0       10  {'kernel': 'poly', 'C': 10}           1.000000           1.000000
# 1       20  {'kernel': 'poly', 'C': 20}           0.966667           0.966667
# 2        1    {'kernel': 'rbf', 'C': 1}           0.966667           1.000000
# 3       30  {'kernel': 'poly', 'C': 30}           0.966667           0.966667
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 0           0.900000           0.933333                1.0         0.966667
# ...

# %%
classifier_r.best_params_
# Out:
# {'kernel': 'rbf', 'C': 1}

# %%
classifier_r.best_score_
# Out:
# np.float64(0.9800000000000001)
